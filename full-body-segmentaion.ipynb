# %% [markdown]
# ## Full body segmentation using Unet architecture.

# %%
import cv2
import matplotlib.pyplot as plt
import numpy as np
import os
import copy
from tqdm import tqdm

import albumentations as A
from albumentations.pytorch import ToTensorV2

import torch
import torch.nn as nn
import torch.nn.functional as F
# Out:
# /opt/conda/lib/python3.10/site-packages/albumentations/__init__.py:24: UserWarning: A new version of Albumentations is available: 1.4.22 (you have 1.4.21). Upgrade using: pip install -U albumentations. To disable automatic update checks, set the environment variable NO_ALBUMENTATIONS_UPDATE to 1.
#   check_for_updates()

# %%
class CNA(nn.Module):
    def __init__(self, in_nc, out_nc, stride=1):
        super().__init__()
        
        self.conv = nn.Conv2d(in_nc, out_nc, 3, stride=stride, padding=1, bias=False)
        self.norm = nn.BatchNorm2d(out_nc)
        self.act = nn.GELU()
    
    def forward(self, x):
        out = self.conv(x)
        out = self.norm(out)
        out = self.act(out)
        
        return out

# %%
class UnetBlock(nn.Module):
    def __init__(self, in_nc, inner_nc, out_nc, inner_block=None):
        super().__init__()
        
        self.conv1 = CNA(in_nc, inner_nc, stride=2)
        self.conv2 = CNA(inner_nc, inner_nc)
        self.inner_block = inner_block
        self.conv3 = CNA(inner_nc, inner_nc)
        self.conv_cat = nn.Conv2d(inner_nc+in_nc, out_nc, 3, padding=1)
        
    def forward(self, x):
        _,_,h,w = x.shape
        
        inner = self.conv1(x)
        inner = self.conv2(inner)
        #print(inner.shape)
        if self.inner_block is not None:
            inner = self.inner_block(inner)
        inner = self.conv3(inner)
        
        inner = F.upsample(inner, size=(h,w), mode='bilinear')
        inner = torch.cat((x, inner), axis=1)
        out = self.conv_cat(inner)
        
        return out

# %%
class Unet(nn.Module):
    def __init__(self, in_nc=1, nc=32, out_nc=1, num_downs=6):
        super().__init__()
        
        self.cna1 = CNA(in_nc, nc)
        self.cna2 = CNA(nc, nc)
        
        unet_block = None
        for i in range(num_downs-3):
            unet_block = UnetBlock(8*nc, 8*nc, 8*nc, unet_block)
        unet_block = UnetBlock(4*nc, 8*nc, 4*nc, unet_block)
        unet_block = UnetBlock(2*nc, 4*nc, 2*nc, unet_block)
        self.unet_block = UnetBlock(nc, 2*nc, nc, unet_block)
        
        self.cna3 = CNA(nc, nc)
        
        self.conv_last = nn.Conv2d(nc, out_nc, 3, padding=1)

    def forward(self, x):
        out = self.cna1(x)
        out = self.cna2(out)
        out = self.unet_block(out)
        out = self.cna3(out)
        out = self.conv_last(out)
        
        return out

# %%
def count_parameters(model):
    return sum(p.numel() for p in model.parameters() if p.requires_grad)

# %%
class MyDataset(torch.utils.data.Dataset):
    def __init__(self,  images_directory, masks_directory, transform=None):
        self.images_directory = images_directory
        self.masks_directory = masks_directory
        self.transform = transform
        
        self.images_filenames = sorted(os.listdir(self.images_directory))

    def __len__(self):
        return len(self.images_filenames)

    def __getitem__(self, idx):
        image_filename = self.images_filenames[idx]
        image = cv2.imread(os.path.join(self.images_directory, image_filename), cv2.IMREAD_COLOR)
        image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
        mask = cv2.imread(os.path.join(self.masks_directory, image_filename), cv2.IMREAD_COLOR)[:,:,0:1]
        image = image.astype(np.float32)/255.0
        mask = mask.astype(np.float32)/255.0
        if self.transform is not None:
            transformed = self.transform(image=image, mask=mask)
            image = transformed["image"]
            mask = transformed["mask"]
            mask = np.transpose(mask, (2,0,1))
            
            #mask = torch.from_numpy(mask)
        return image, mask

# %%
train_transform = A.Compose(
    [
        A.PadIfNeeded(min_height=256, min_width=256),
        A.RandomCrop(256, 256),
        A.ShiftScaleRotate(shift_limit=0.05, scale_limit=0.05, rotate_limit=15, p=0.5),
        #A.RGBShift(r_shift_limit=15, g_shift_limit=15, b_shift_limit=15, p=0.5),
        #A.RandomBrightnessContrast(p=0.5),
        #A.Normalize(mean=(1.0, 1.0, 1.0), std=(1.0, 1.0, 1.0)),
        ToTensorV2(),
    ]
)

val_transform = A.Compose(
    [
        A.PadIfNeeded(min_height=256, min_width=256),
        A.CenterCrop(256, 256),
        #A.Normalize(mean=(0.485, 0.456, 0.406), std=(0.229, 0.224, 0.225)),
        ToTensorV2(),
    ]
)

# %%
common_path = '/kaggle/input/segmentation-full-body-mads-dataset/segmentation_full_body_mads_dataset_1192_img/segmentation_full_body_mads_dataset_1192_img'

ds_images_path = common_path + '/images'
ds_masks_path = common_path + '/masks'

# %%
ds_train = MyDataset(ds_images_path, ds_masks_path, transform=train_transform)

# %%
def visualize_augmentations(dataset, idx=0, samples=5):
    dataset = copy.deepcopy(dataset)
    dataset.transform = A.Compose([t for t in dataset.transform if not isinstance(t, (A.Normalize, ToTensorV2))])
    figure, ax = plt.subplots(nrows=samples, ncols=2, figsize=(10, 24))
    for i in range(samples):
        image, mask = dataset[idx]
        mask = np.transpose(mask, (1,2,0))
        ax[i, 0].imshow(image)
        ax[i, 1].imshow(mask, interpolation="nearest")
        ax[i, 0].set_title("Augmented image")
        ax[i, 1].set_title("Augmented mask")
        ax[i, 0].set_axis_off()
        ax[i, 1].set_axis_off()
    plt.tight_layout()
    plt.show()

# %%
visualize_augmentations(ds_train, 0)

# %%
batch_size = 16
train_loader = torch.utils.data.DataLoader(
    ds_train, shuffle=True, 
    batch_size=batch_size, num_workers=1, drop_last=True
)

device = 'cuda'
unet_model = Unet(in_nc=3, nc=32, out_nc=1, num_downs=5)
unet_model = unet_model.to(device)

loss_fn = nn.BCEWithLogitsLoss()
optimizer = torch.optim.Adam(unet_model.parameters(), lr=0.001, betas=(0.9, 0.999))
scheduler = torch.optim.lr_scheduler.ExponentialLR(optimizer, gamma=0.9)

# %%
count_parameters(unet_model)
# Out:
# 8440481

# %%
# Remove all warning
import warnings
warnings.filterwarnings('ignore')

epochs = 10
for epoch in range(epochs):
    loss_val = 0
    acc_val = 0
    for sample in (pbar := tqdm(train_loader)):
        img, mask = sample
        img = img.to(device)
        mask = mask.to(device)
        optimizer.zero_grad()
        
        pred = unet_model(img)
        loss = loss_fn(pred, mask)

        loss.backward()
        loss_item = loss.item()
        loss_val += loss_item

        optimizer.step()
    
    scheduler.step()
    #pbar.set_description(f'loss: {loss_item:.5f}\tlr: {scheduler.get_last_lr}')
    print(f'{loss_val/len(train_loader)}\t lr: {scheduler.get_last_lr()}')
    #print()
# Out:
#   0%|          | 0/74 [00:00<?, ?it/s]libpng warning: iCCP: known incorrect sRGB profile
# libpng warning: iCCP: known incorrect sRGB profile
# libpng warning: iCCP: known incorrect sRGB profile
# libpng warning: iCCP: known incorrect sRGB profile
# libpng warning: iCCP: known incorrect sRGB profile
# libpng warning: iCCP: known incorrect sRGB profile
#   1%|▏         | 1/74 [00:02<02:32,  2.09s/it]libpng warning: iCCP: known incorrect sRGB profile
# libpng warning: iCCP: known incorrect sRGB profile
#   3%|▎         | 2/74 [00:02<01:15,  1.05s/it]libpng warning: iCCP: known incorrect sRGB profile
#   4%|▍         | 3/74 [00:02<00:51,  1.38it/s]libpng warning: iCCP: known incorrect sRGB profile
# libpng warning: iCCP: known incorrect sRGB profile
#   7%|▋         | 5/74 [00:03<00:38,  1.78it/s]libpng warning: iCCP: known incorrect sRGB profile
#   8%|▊         | 6/74 [00:04<00:38,  1.79it/s]libpng warning: iCCP: known incorrect sRGB profile
#  11%|█         | 8/74 [00:05<00:38,  1.70it/s]libpng warning: iCCP: known incorrect sRGB profile
# libpng warning: iCCP: known incorrect sRGB profile
#  14%|█▎        | 10/74 [00:06<00:39,  1.62it/s]libpng warning: iCCP: known incorrect sRGB profile
#  15%|█▍        | 11/74 [00:07<00:39,  1.59it/s]libpng warning: iCCP: known incorrect sRGB profile
#  16%|█▌        | 12/74 [00:07<00:38,  1.61it/s]libpng warning: iCCP: known incorrect sRGB profile
#  22%|██▏       | 16/74 [00:10<00:36,  1.60it/s]libpng warning: iCCP: known incorrect sRGB profile
#  23%|██▎       | 17/74 [00:11<00:36,  1.58it/s]libpng warning: iCCP: known incorrect sRGB profile
#  28%|██▊       | 21/74 [00:13<00:32,  1.63it/s]libpng warning: iCCP: known incorrect sRGB profile
# libpng warning: iCCP: known incorrect sRGB profile
#  30%|██▉       | 22/74 [00:14<00:32,  1.59it/s]libpng warning: iCCP: known incorrect sRGB profile
# libpng warning: iCCP: known incorrect sRGB profile
# libpng warning: iCCP: known incorrect sRGB profile
#  31%|███       | 23/74 [00:14<00:31,  1.61it/s]libpng warning: iCCP: known incorrect sRGB profile
#  32%|███▏      | 24/74 [00:15<00:31,  1.59it/s]libpng warning: iCCP: known incorrect sRGB profile
#  34%|███▍      | 25/74 [00:16<00:31,  1.58it/s]libpng warning: iCCP: known incorrect sRGB profile
#  35%|███▌      | 26/74 [00:16<00:31,  1.54it/s]libpng warning: iCCP: known incorrect sRGB profile
#  36%|███▋      | 27/74 [00
  2.68it/s]libpng warning: iCCP: known incorrect sRGB profile
# libpng warning: iCCP: known incorrect sRGB profile
# 100%|██████████| 74/74 [00:27<00:00,  2.67it/s]
# 0.03254988182940193	 lr: [0.000531441]
#   0%|          | 0/74 [00:00<?, ?it/s]libpng warning: iCCP: known incorrect sRGB profile
# libpng warning: iCCP: known incorrect sRGB profile
# libpng warning: iCCP: known incorrect sRGB profile
# libpng warning: iCCP: known incorrect sRGB profile
# libpng warning: iCCP: known incorrect sRGB profile
#   1%|▏         | 1/74 [00:00<00:48,  1.51it/s]libpng warning: iCCP: known incorrect sRGB profile
# libpng warning: iCCP: known incorrect sRGB profile
#   3%|▎         | 2/74 [00:01<00:35,  2.03it/s]libpng warning: iCCP: known incorrect sRGB profile
# libpng warning: iCCP: known incorrect sRGB profile
#   4%|▍         | 3/74 [00:01<00:31,  2.28it/s]libpng warning: iCCP: known incorrect sRGB profile
#   5%|▌         | 4/74 [00:01<00:28,  2.42it/s]libpng warning: iCCP: known incorrect sRGB profile
# libpng warning: iCCP: known incorrect sRGB profile
#   8%|▊         | 6/74 [00:02<00:26,  2.56it/s]libpng warning: iCCP: known incorrect sRGB profile
# libpng warning: iCCP: known incorrect sRGB profile
#   9%|▉         | 7/74 [00:02<00:25,  2.60it/s]libpng warning: iCCP: known incorrect sRGB profile
# ...
#   1%|▏         | 1/74 [00:00<00:48,  1.50it/s]libpng warning: iCCP: known incorrect sRGB profile
# libpng warning: iCCP: known incorrect sRGB profile
#   3%|▎         | 2/74 [00:01<00:35,  2.02it/s]libpng warning: iCCP: known incorrect sRGB profile
# libpng warning: iCCP: known incorrect sRGB profile
# libpng warning: iCCP: known incorrect sRGB profile
#   4%|▍         | 3/74 [00:01<00:31,  2.29it/s]libpng warning: iCCP: known incorrect sRGB profile
# libpng warning: iCCP: known incorrect sRGB profile
#   5%|▌         | 4/74 [00:01<00:28,  2.44it/s]libpng warning: iCCP: known incorrect sRGB profile
# libpng warning: iCCP: known incorrect sRGB profile
# libpng warning: iCCP: known incorrect sRGB profile
#   8%|▊         | 6/74 [00:02<00:26,  2.58it/s]libpng warning: iCCP: known incorrect sRGB profile
#   9%|▉         | 7/74 [00:02<00:25,  2.62it/s]libpng warning: iCCP: known incorrect sRGB profile
#  11%|█         | 8/74 [00:03<00:24,  2.65it/s]libpng warning: iCCP: known incorrect sRGB profile
#  14%|█▎        | 10/74 [00:04<00:23,  2.67it/s]libpng warning: iCCP: known incorrect sRGB profile
#  15%|█▍        | 11/74 [00:04<00:23,  2.68it/s]libpng warning: iCCP: known incorrect sRGB profile
#  16%|█▌        | 12/74 [00:04<00:23,  2.67it/s]libpng warning: iCCP: known incorrect sRGB profile
#  19%|█▉        | 14/74 [00:05<00:22,  2.69it/s]libpng warning: iCCP: known incorrect sRGB profile
#  20%|██        | 15/74 [00:05<00:21,  2.68it/s]libpng warning: iCCP: known incorrect sRGB profile
#  22%|██▏       | 16/74 [00:06<00:21,  2.69it/s]libpng warning: iCCP: known incorrect sRGB profile
# libpng warning: iCCP: known incorrect sRGB profile
# libpng warning: iCCP: known incorrect sRGB profile
#  24%|██▍       | 18/74 [00:06<00:20,  2.68it/s]libpng warning: iCCP: known incorrect sRGB profile
# libpng warning: iCCP: known incorrect sRGB profile
#  27%|██▋       | 20/74 [00:07<00:20,  2.68it/s]libpng warning: iCCP: known incorrect sRGB profile
#  28%|██▊       | 21/74 [00:08<00:19,  2.68it/s]libpng warning: iCCP: known incorrect sRGB profile
# libpng warning: iCCP: known incorrect sRGB profile
#  31%|███       | 23/74 [00:08<00:18,  2.68it/s]libpng warning: iCCP: known incorrect sRGB profile
# libpng warning: iCCP: known incorrect sRGB profile
#  32%|███▏      | 24/74 [00:09<00:18,  2.69it/s]libpng warning: iCCP: known incorrect sRGB profile
# libpng warning: iCCP: known incorrect sRGB profile
#  36%|███▋      | 27/74 [00:10<00:17,  2.70it/s]libpng warning: iCCP: known incorrect sRGB profile
# libpng warning: iCCP: known incorrect sRGB profile
#  38%|███▊      | 28/74 [00:10<00:17,  2.69it/s]libpng warning: iCCP: known incorrect sRGB profile
# libpng warning: iCCP: known incorrect sRGB profile
#  39%|███▉      | 29/74 [00:11<00:16,  2.69it/s]libpng warning: iCCP: known incorrect sRGB profile
#  41%|████      | 30/74 [00:11<00:16,  2.68it/s]libpng warning: iCCP: known incorrect sRGB profile
#  42%|████▏     | 31/74 [00:11<00:15,  2.69it/s]libpng warning: iCCP: known incorrect sRGB profile
#  43%|████▎     | 32/74 [00:12<00:15,  2.70it/s]libpng warning: iCCP: known incorrect sRGB profile
# libpng warning: iCCP: known incorrect sRGB profile
# libpng warning: iCCP: known incorrect sRGB profile
#  46%|████▌     | 34/74 [00:12<00:14,  2.69it/s]libpng warning: iCCP: known incorrect sRGB profile
#  47%|████▋     | 35/74 [00:13<00:14,  2.69it/s]libpng warning: iCCP: known incorrect sRGB profile
# libpng warning: iCCP: known incorrect sRGB profile
# libpng warning: iCCP: known incorrect sRGB profile
#  49%|████▊     | 36/74 [00:13<00:14,  2.69it/s]libpng warning: iCCP: known incorrect sRGB profile
#  50%|█████     | 37/74 [00:14<00:13,  2.70it/s]libpng warning: iCCP: known incorrect sRGB profile
# libpng warning: iCCP: known incorrect sRGB profile
#  51%|█████▏    | 38/74 [00:14<00:13,  2.70it/s]libpng warning: iCCP: known incorrect sRGB profile
#  53%|█████▎    | 39/74 [00:14<00:13,  2.69it/s]libpng warning: iCCP: known incorrect sRGB profile
#  54%|█████▍    | 40/74 [00:15<00:12,  2.70it/s]libpng warning: iCCP: known incorrect sRGB profile
#  55%|█████▌    | 41/74 [00:15<00:12,  2.70it/s]libpng warning: iCCP: known incorrect sRGB profile
#  57%|█████▋    | 42/74 [00:15<00:11,  2.69it/s]libpng warning: iCCP: known incorrect sRGB profile
# libpng warning: iCCP: known incorrect sRGB profile
# libpng warning: iCCP: known incorrect sRGB profile
#  59%|█████▉    | 44/74 [00:16<00:11,  2.70it/s]libpng warning: iCCP: known incorrect sRGB profile
#  61%|██████    | 45/74 [00:17<00:10,  2.69it/s]libpng warning: iCCP: known incorrect sRGB profile
# libpng warning: iCCP: known incorrect sRGB profile
# libpng warning: iCCP: known incorrect sRGB profile
#  62%|██████▏   | 46/74 [00:17<00:10,  2.69it/s]libpng warning: iCCP: known incorrect sRGB profile
# libpng warning: iCCP: known incorrect sRGB profile
# libpng warning: iCCP: known incorrect sRGB profile
# libpng warning: iCCP: known incorrect sRGB profile
# libpng warning: iCCP: known incorrect sRGB profile
#  64%|██████▎   | 47/74 [00:17<00:10,  2.69it/s]libpng warning: iCCP: known incorrect sRGB profile
#  65%|██████▍   | 48/74 [00:18<00:09,  2.69it/s]libpng warning: iCCP: known incorrect sRGB profile
#  66%|██████▌   | 49/74 [00:18<00:09,  2.68it/s]libpng warning: iCCP: known incorrect sRGB profile
# libpng warning: iCCP: known incorrect sRGB profile
# libpng warning: iCCP: known incorrect sRGB profile
#  69%|██████▉   | 51/74 [00:19<00:08,  2.69it/s]libpng warning: iCCP: known incorrect sRGB profile
# libpng warning: iCCP: known incorrect sRGB profile
#  70%|███████   | 52/74 [00:19<00:08,  2.69it/s]libpng warning: iCCP: known incorrect sRGB profile
#  72%|███████▏  | 53/74 [00:19<00:07,  2.70it/s]libpng warning: iCCP: known incorrect sRGB profile
#  73%|███████▎  | 54/74 [00:20<00:07,  2.70it/s]libpng warning: iCCP: known incorrect sRGB profile
#  74%|███████▍  | 55/74 [00:20<00:07,  2.69it/s]libpng warning: iCCP: known incorrect sRGB profile
# libpng warning: iCCP: known incorrect sRGB profile
#  76%|███████▌  | 56/74 [00:21<00:06,  2.69it/s]libpng warning: iCCP: known incorrect sRGB profile
#  77%|███████▋  | 57/74 [00:21<00:06,  2.68it/s]libpng warning: iCCP: known incorrect sRGB profile
#  81%|████████  | 60/74 [00:22<00:05,  2.69it/s]libpng warning: iCCP: known incorrect sRGB profile
# libpng warning: iCCP: known incorrect sRGB profile
# libpng warning: iCCP: known incorrect sRGB profile
#  84%|████████▍ | 62/74 [00:23<00:04,  2.70it/s]libpng warning: iCCP: known incorrect sRGB profile
# libpng warning: iCCP: known incorrect sRGB profile
# libpng warning: iCCP: known incorrect sRGB profile
#  85%|████████▌ | 63/74 [00:23<00:04,  2.69it/s]libpng warning: iCCP: known incorrect sRGB profile
#  86%|████████▋ | 64/74 [00:24<00:03,  2.70it/s]libpng warning: iCCP: known incorrect sRGB profile
# libpng warning: iCCP: known incorrect sRGB profile
#  88%|████████▊ | 65/74 [00:24<00:03,  2.70it/s]libpng warning: iCCP: known incorrect sRGB profile
# libpng warning: iCCP: known incorrect sRGB profile
#  89%|████████▉ | 66/74 [00:24<00:02,  2.70it/s]libpng warning: iCCP: known incorrect sRGB profile
#  91%|█████████ | 67/74 [00:25<00:02,  2.69it/s]libpng warning: iCCP: known incorrect sRGB profile
# libpng warning: iCCP: known incorrect sRGB profile
# libpng warning: iCCP: known incorrect sRGB profile
# libpng warning: iCCP: known incorrect sRGB profile
#  92%|█████████▏| 68/74 [00:25<00:02,  2.70it/s]libpng warning: iCCP: known incorrect sRGB profile
#  93%|█████████▎| 69/74 [00:25<00:01,  2.70it/s]libpng warning: iCCP: known incorrect sRGB profile
# libpng warning: iCCP: known incorrect sRGB profile
#  95%|█████████▍| 70/74 [00:26<00:01,  2.69it/s]libpng warning: iCCP: known incorrect sRGB profile
#  96%|█████████▌| 71/74 [00:26<00:01,  2.70it/s]libpng warning: iCCP: known incorrect sRGB profile
# 100%|██████████| 74/74 [00:27<00:00,  2.66it/s]
# 0.022923344469352347	 lr: [0.000387420489]
#   0%|          | 0/74 [00:00<?, ?it/s]libpng warning: iCCP: known incorrect sRGB profile
# libpng warning: iCCP: known incorrect sRGB profile
#   1%|▏         | 1/74 [00:00<00:48,  1.50it/s]libpng warning: iCCP: known incorrect sRGB profile
#   3%|▎         | 2/74 [00:01<00:35,  2.02it/s]libpng warning: iCCP: known incorrect sRGB profile
#   4%|▍         | 3/74 [00:01<00:31,  2.28it/s]libpng warning: iCCP: known incorrect sRGB profile
#   5%|▌         | 4/74 [00:01<00:28,  2.42it/s]libpng warning: iCCP: known incorrect sRGB profile
#   7%|▋         | 5/74 [00:02<00:27,  2.51it/s]libpng warning: iCCP: known incorrect sRGB profile
#   8%|▊         | 6/74 [00:02<00:26,  2.56it/s]libpng warning: iCCP: known incorrect sRGB profile
#   9%|▉         | 7/74 [00:02<00:25,  2.61it/s]libpng warning: iCCP: known incorrect sRGB profile
#  11%|█         | 8/74 [00:03<00:25,  2.63it/s]libpng warning: iCCP: known incorrect sRGB profile
# libpng warning: iCCP: known incorrect sRGB profile
# libpng warning: iCCP: known incorrect sRGB profile
#  12%|█▏        | 9/74 [00:03<00:24,  2.65it/s]libpng warning: iCCP: known incorrect sRGB profile
# libpng warning: iCCP: known incorrect sRGB profile
#  15%|█▍        | 11/74 [00:04<00:23,  2.68it/s]libpng warning: iCCP: known incorrect sRGB profile
#  16%|█▌        | 12/74 [00:04<00:23,  2.67it/s]libpng warning: iCCP: known incorrect sRGB profile
#  18%|█▊        | 13/74 [00:05<00:22,  2.69it/s]libpng warning: iCCP: known incorrect sRGB profile
# libpng warning: iCCP: known incorrect sRGB profile
# libpng warning: iCCP: known incorrect sRGB profile
# libpng warning: iCCP: known incorrect sRGB profile
#  19%|█▉        | 14/74 [00:05<00:22,  2.68it/s]libpng warning: iCCP: known incorrect sRGB profile
#  20%|██        | 15/74 [00:05<00:21,  2.69it/s]libpng warning: iCCP: known incorrect sRGB profile
#  22%|██▏       | 16/74 [00:06<00:21,  2.69it/s]libpng warning: iCCP: known incorrect sRGB profile
#  24%|██▍       | 18/74 [00:06<00:20,  2.69it/s]libpng warning: iCCP: known incorrect sRGB profile
# libpng warning: iCCP: known incorrect sRGB profile
#  26%|██▌       | 19/74 [00:07<00:20,  2.70it/s]libpng warning: iCCP: known incorrect sRGB profile
#  27%|██▋       | 20/74 [00:07<00:20,  2.70it/s]libpng warning: iCCP: known incorrect sRGB profile
#  28%|██▊       | 21/74 [00:08<00:19,  2.69it/s]libpng warning: iCCP: known incorrect sRGB profile
#  30%|██▉       | 22/74 [00:08<00:19,  2.69it/s]libpng warning: iCCP: known incorrect sRGB profile
# libpng warning: iCCP: known incorrect sRGB profile
#  31%|███       | 23/74 [00:08<00:18,  2.69it/s]libpng warning: iCCP: known incorrect sRGB profile
#  32%|███▏      | 24/74 [00:09<00:18,  2.70it/s]libpng warning: iCCP: known incorrect sRGB profile
# libpng warning: iCCP: known incorrect sRGB profile
#  35%|███▌      | 26/74 [00:09<00:17,  2.69it/s]libpng warning: iCCP: known incorrect sRGB profile
#  36%|███▋      | 27/74 [00:10<00:17,  2.69it/s]libpng warning: iCCP: known incorrect sRGB profile
# libpng warning: iCCP: known incorrect sRGB profile
# libpng warning: iCCP: known incorrect sRGB profile
#  39%|███▉      | 29/74 [00:11<00:16,  2.69it/s]libpng warning: iCCP: known incorrect sRGB profile
#  41%|████      | 30/74 [00:11<00:16,  2.70it/s]libpng warning: iCCP: known incorrect sRGB profile
# libpng warning: iCCP: known incorrect sRGB profile
#  43%|████▎     | 32/74 [00:12<00:15,  2.70it/s]libpng warning: iCCP: known incorrect sRGB profile
# libpng warning: iCCP: known incorrect sRGB profile
#  45%|████▍     | 33/74 [00:12<00:15,  2.70it/s]libpng warning: iCCP: known incorrect sRGB profile
#  46%|████▌     | 34/74 [00:12<00:14,  2.70it/s]libpng warning: iCCP: known incorrect sRGB profile
#  47%|████▋     | 35/74 [00:13<00:14,  2.69it/s]libpng warning: iCCP: known incorrect sRGB profile
# libpng warning: iCCP: known incorrect sRGB profile
#  51%|█████▏    | 38/74 [00:14<00:13,  2.69it/s]libpng warning: iCCP: known incorrect sRGB profile
#  53%|█████▎    | 39/74 [00:14<00:12,  2.70it/s]libpng warning: iCCP: known incorrect sRGB profile
#  54%|█████▍    | 40/74 [00:15<00:12,  2.70it/s]libpng warning: iCCP: known incorrect sRGB profile
# libpng warning: iCCP: known incorrect sRGB profile
#  55%|█████▌    | 41/74 [00:15<00:12,  2.69it/s]libpng warning: iCCP: known incorrect sRGB profile
# libpng warning: iCCP: known incorrect sRGB profile
#  58%|█████▊    | 43/74 [00:16<00:11,  2.69it/s]libpng warning: iCCP: known incorrect sRGB profile
# libpng warning: iCCP: known incorrect sRGB profile
#  59%|█████▉    | 44/74 [00:16<00:11,  2.69it/s]libpng warning: iCCP: known incorrect sRGB profile
#  61%|██████    | 45/74 [00:16<00:10,  2.70it/s]libpng warning: iCCP: known incorrect sRGB profile
# libpng warning: iCCP: known incorrect sRGB profile
#  62%|██████▏   | 46/74 [00:17<00:10,  2.69it/s]libpng warning: iCCP: known incorrect sRGB profile
# libpng warning: iCCP: known incorrect sRGB profile
# libpng warning: iCCP: known incorrect sRGB profile
# libpng warning: iCCP: known incorrect sRGB profile
#  65%|██████▍   | 48/74 [00:18<00:09,  2.68it/s]libpng warning: iCCP: known incorrect sRGB profile
#  66%|██████▌   | 49/74 [00:18<00:09,  2.69it/s]libpng warning: iCCP: known incorrect sRGB profile
# libpng warning: iCCP: known incorrect sRGB profile
#  68%|██████▊   | 50/74 [00:18<00:08,  2.69it/s]libpng warning: iCCP: known incorrect sRGB profile
# libpng warning: iCCP: known incorrect sRGB profile
#  69%|██████▉   | 51/74 [00:19<00:08,  2.69it/s]libpng warning: iCCP: known incorrect sRGB profile
#  70%|███████   | 52/74 [00:19<00:08,  2.69it/s]libpng warning: iCCP: known incorrect sRGB profile
#  72%|███████▏  | 53/74 [00:19<00:07,  2.69it/s]libpng warning: iCCP: known incorrect sRGB profile
#  73%|███████▎  | 54/74 [00:20<00:07,  2.69it/s]libpng warning: iCCP: known incorrect sRGB profile
# libpng warning: iCCP: known incorrect sRGB profile
# libpng warning: iCCP: known incorrect sRGB profile
#  74%|███████▍  | 55/74 [00:20<00:07,  2.69it/s]libpng warning: iCCP: known incorrect sRGB profile
# libpng warning: iCCP: known incorrect sRGB profile
# libpng warning: iCCP: known incorrect sRGB profile
#  76%|███████▌  | 56/74 [00:21<00:06,  2.68it/s]libpng warning: iCCP: known incorrect sRGB profile
# libpng warning: iCCP: known incorrect sRGB profile
# libpng warning: iCCP: known incorrect sRGB profile
#  77%|███████▋  | 57/74 [00:21<00:06,  2.68it/s]libpng warning: iCCP: known incorrect sRGB profile
#  80%|███████▉  | 59/74 [00:22<00:05,  2.68it/s]libpng warning: iCCP: known incorrect sRGB profile
# libpng warning: iCCP: known incorrect sRGB profile
#  81%|████████  | 60/74 [00:22<00:05,  2.67it/s]libpng warning: iCCP: known incorrect sRGB profile
#  82%|████████▏ | 61/74 [00:22<00:04,  2.68it/s]libpng warning: iCCP: known incorrect sRGB profile
#  84%|████████▍ | 62/74 [00:23<00:04,  2.69it/s]libpng warning: iCCP: known incorrect sRGB profile
# libpng warning: iCCP: known incorrect sRGB profile
# libpng warning: iCCP: known incorrect sRGB profile
# libpng warning: iCCP: known incorrect sRGB profile
#  85%|████████▌ | 63/74 [00:23<00:04,  2.69it/s]libpng warning: iCCP: known incorrect sRGB profile
#  86%|████████▋ | 64/74 [00:24<00:03,  2.69it/s]libpng warning: iCCP: known incorrect sRGB profile
#  88%|████████▊ | 65/74 [00:24<00:03,  2.70it/s]libpng warning: iCCP: known incorrect sRGB profile
# libpng warning: iCCP: known incorrect sRGB profile
# libpng warning: iCCP: known incorrect sRGB profile
#  89%|████████▉ | 66/74 [00:24<00:02,  2.69it/s]libpng warning: iCCP: known incorrect sRGB profile
# libpng warning: iCCP: known incorrect sRGB profile
#  91%|█████████ | 67/74 [00:25<00:02,  2.69it/s]libpng warning: iCCP: known incorrect sRGB profile
#  92%|█████████▏| 68/74 [00:25<00:02,  2.69it/s]libpng warning: iCCP: known incorrect sRGB profile
#  93%|█████████▎| 69/74 [00:25<00:01,  2.69it/s]libpng warning: iCCP: known incorrect sRGB profile
# libpng warning: iCCP: known incorrect sRGB profile
#  95%|█████████▍| 70/74 [00:26<00:01,  2.70it/s]libpng warning: iCCP: known incorrect sRGB profile
#  96%|█████████▌| 71/74 [00:26<00:01,  2.69it/s]libpng warning: iCCP: known incorrect sRGB profile
# libpng warning: iCCP: known incorrect sRGB profile
# libpng warning: iCCP: known incorrect sRGB profile
# 100%|██████████| 74/74 [00:27<00:00,  2.66it/s]
# 0.02502893877995981	 lr: [0.0003486784401]

# %%
img = ds_train[10][0].unsqueeze(0)
pred = unet_model(img.cuda())
pred = F.sigmoid(pred.detach()).cpu().numpy()[0].transpose(1,2,0)

# %%
img_np = img.detach().cpu().numpy()[0].transpose(1,2,0)
plt.imshow(img_np)

# %%
plt.imshow(pred)
